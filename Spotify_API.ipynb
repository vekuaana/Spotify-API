# %% [markdown]
# # Python Spotify API

# %% [markdown]
# #### Introduction

# %% [markdown]
# Spotify Web API enables the creation of applications that can interact with Spotify's streaming service, such as retrieving content metadata, getting recommendations, creating and managing playlists, or controlling playback (https://developer.spotify.com/documentation/web-api)
#
# In the following project, we are going to extract data ( the top 10 tracks of any artist) using Python and the Spotify Web API. The steps followed are:
# - Create a Client ID and a Client Secret. To do so, follow the step on the Spotify Web API documentation (https://developer.spotify.com/documentation/web-api/concepts/apps) <br>
# - Generate your access token
# - Call the request you are interested in. In this exercise, we are going to retrieve the Top 10 most popular songs of a Spotify artist. We will use the Get Artist's Top Tracks request (https://developer.spotify.com/documentation/web-api/reference/get-an-artists-top-tracks)

# %% [markdown]
# #### Client Credentials Flow
# https://developer.spotify.com/documentation/web-api/tutorials/client-credentials-flow

# %%
import requests
import base64
from requests import post
import json

client_id = "afb7e3d8170141e0a73470e95e2757ec"
client_secret ="f4b1b0dcba2f48f190cf571fec5c83e1"

#Ask for a Spotify Token
def get_token():
    auth_string = client_id + ":" + client_secret
    auth_bytes = auth_string.encode("utf-8") #encoding
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": "Basic " + auth_base64,
        "Content-Type" :"application/x-www-form-urlencoded"
    }
    data = {"grant_type":"client_credentials"}
    result = post(url, headers=headers, data = data) #Make a POST request to a web page, and return the response text
    json_result=json.loads(result.content)
    token = json_result["access_token"]
    return token

# %%
token = get_token()

def get_auth_header(token):
        return {"Authorization": "Bearer " + token }

# %% [markdown]
# #### Get the most played track of an artist
# Search for item: https://developer.spotify.com/documentation/web-api/reference/search
# Get

# %%
def search_artist(token, artist_name):
    url = 'https://api.spotify.com/v1/search'
    headers = get_auth_header(token)
    query = f'?q={artist_name}&type=artist&limit=1'#select the first artist of the search
    query_url = url + query 
    result = get(query_url, headers=headers)
    json_result=json.loads(result.content)

    if len(json_result) == 0:
        print("No artist with that name exist.")
        return None
        
    return json_result
    
def get_artist_top_tracks(token, artist_name):
    headers = get_auth_header(token)
    search = search_artist(token, artist_name)
    id = search['artists']['items'][0]['id']
    print(id)
    url = f'https://api.spotify.com/v1/artists/{id}/top-tracks?market=BE'
    result = get(url, headers=headers)
    print(result)
    json_result=json.loads(result.content)['tracks']
    return json_result

# %%
songs = get_artist_top_tracks(token, "pomme")
# Out:
# 6e3pZKXUxrPfnUPJ960Hd9
# <Response [200]>

# %%
songs
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#      'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#      'id': '6e3pZKXUxrPfnUPJ960Hd9',
#      'name': 'Pomme',
#      'type': 'artist',
#      'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/65JwIioaq6D5ExpRdtYpCM'},
#    'href': 'https://api.spotify.com/v1/albums/65JwIioaq6D5ExpRdtYpCM',
#    'id': '65JwIioaq6D5ExpRdtYpCM',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736ada6a0f014e5ca796561339',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026ada6a0f014e5ca796561339',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516ada6a0f014e5ca796561339',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'À peu près',
#    'release_date': '2017-10-06',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:65JwIioaq6D5ExpRdtYpCM'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#     'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#     'id': '6e3pZKXUxrPfnUPJ960Hd9',
#     'name': 'Pomme',
#     'type': 'artist',
#     'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#   'disc_number': 1,
#   'duration_ms': 118386,
#   'explicit': False,
#   'external_ids': {'isrc': 'FRUM71700924'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7as88HhLbDLgobaSbJrVBs'},
#   'href': 'https://api.spotify.com/v1/tracks/7as88HhLbDLgobaSbJrVBs',
#   'id': '7as88HhLbDLgobaSbJrVBs',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Ceux qui rêvent',
#   'popularity': 65,
#   'preview_url': None,
#   'track_number': 11,
#   'type': 'track',
#   'uri': 'spotify:track:7as88HhLbDLgobaSbJrVBs'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1sJDvsoQ9X10dibPnSSlsV'},
#      'href': 'https://api.spotify.com/v1/artists/1sJDvsoQ9X10dibPnSSlsV',
#      'id': '1sJDvsoQ9X10dibPnSSlsV',
#      'name': 'Waxx',
#      'type': 'artist',
#      'uri': 'spotify:artist:1sJDvsoQ9X10dibPnSSlsV'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#      'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#      'id': '6e3pZKXUxrPfnUPJ960Hd9',
#      'name': 'Pomme',
#      'type': 'artist',
#      'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/66BR3VEZqTOgclJxBlClQK'},
#    'href': 'https://api.spotify.com/v1/albums/66BR3VEZqTOgclJxBlClQK',
#    'id': '66BR3VEZqTOgclJxBlClQK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27349f1288a7625298909681b68',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0249f1288a7625298909681b68',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485149f1288a7625298909681b68',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Laissez-moi danser',
#    'release_date': '2023-06-23',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:66BR3VEZqTOgclJxBlClQK'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1sJDvsoQ9X10dibPnSSlsV'},
#     'href': 'https://api.spotify.com/v1/artists/1sJDvsoQ9X10dibPnSSlsV',
#     'id': '1sJDvsoQ9X10dibPnSSlsV',
#     'name': 'Waxx',
#     'type': 'artist',
#     'uri': 'spotify:artist:1sJDvsoQ9X10dibPnSSlsV'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#     'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#     'id': '6e3pZKXUxrPfnUPJ960Hd9',
#     'name': 'Pomme',
#     'type': 'artist',
#     'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#   'disc_number': 1,
#   'duration_ms': 172360,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR79W2300380'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1LBLEAMse3jta25SKwGs37'},
#   'href': 'https://api.spotify.com/v1/tracks/1LBLEAMse3jta25SKwGs37',
#   'id': '1LBLEAMse3jta25SKwGs37',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Laissez-moi danser',
#   'popularity': 62,
#   'preview_url': 'https://p.scdn.co/mp3-preview/8b01f5d731fd1481eee3424a1a59171b057d19ea?cid=afb7e3d8170141e0a73470e95e2757ec',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:1LBLEAMse3jta25SKwGs37'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5CtPAGoxpJ4yLJLx6CSrO8'},
#      'href': 'https://api.spotify.com/v1/artists/5CtPAGoxpJ4yLJLx6CSrO8',
#      'id': '5CtPAGoxpJ4yLJLx6CSrO8',
#      'name': 'Zamdane',
#      'type': 'artist',
#      'uri': 'spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0fZgRt7DLwwWSErSJjJAiP'},
#    'href': 'https://api.spotify.com/v1/albums/0fZgRt7DLwwWSErSJjJAiP',
#    'id': '0fZgRt7DLwwWSErSJjJAiP',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273483d23d7490a266a042aa0b2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02483d23d7490a266a042aa0b2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851483d23d7490a266a042aa0b2',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'SOLSAD',
#    'release_date': '2024-02-22',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:0fZgRt7DLwwWSErSJjJAiP'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5CtPAGoxpJ4yLJLx6CSrO8'},
#     'href': 'https://api.spotify.com/v1/artists/5CtPAGoxpJ4yLJLx6CSrO8',
#     'id': '5CtPAGoxpJ4yLJLx6CSrO8',
#     'name': 'Zamdane',
#     'type': 'artist',
#     'uri': 'spotify:artist:5CtPAGoxpJ4yLJLx6CSrO8'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#     'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#     'id': '6e3pZKXUxrPfnUPJ960Hd9',
#     'name': 'Pomme',
#     'type': 'artist',
#     'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#   'disc_number': 1,
#   'duration_ms': 241760,
#   'explicit': True,
#   'external_ids': {'isrc': 'FR9W12361886'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3SWrOyTKWQHujERKjMBT6v'},
#   'href': 'https://api.spotify.com/v1/tracks/3SWrOyTKWQHujERKjMBT6v',
#   'id': '3SWrOyTKWQHujERKjMBT6v',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Le grand cirque',
#   'popularity': 54,
#   'preview_url': None,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:3SWrOyTKWQHujERKjMBT6v'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#      'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#      'id': '6e3pZKXUxrPfnUPJ960Hd9',
#      'name': 'Pomme',
#      'type': 'artist',
#      'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3Iq43NGfIN8tc8AVJ9Konz'},
#    'href': 'https://api.spotify.com/v1/albums/3Iq43NGfIN8tc8AVJ9Konz',
#    'id': '3Iq43NGfIN8tc8AVJ9Konz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27330bc1c0c2e0d7cb718f856f2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0230bc1c0c2e0d7cb718f856f2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485130bc1c0c2e0d7cb718f856f2',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'les failles',
#    'release_date': '2019-11-01',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:3Iq43NGfIN8tc8AVJ9Konz'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#     'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#     'id': '6e3pZKXUxrPfnUPJ960Hd9',
#     'name': 'Pomme',
#     'type': 'artist',
#     'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#   'disc_number': 1,
#   'duration_ms': 157866,
#   'explicit': False,
#   'external_ids': {'isrc': 'FRUM71900920'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6m3ObG4d6M92hJWYplJfnb'},
#   'href': 'https://api.spotify.com/v1/tracks/6m3ObG4d6M92hJWYplJfnb',
#   'id': '6m3ObG4d6M92hJWYplJfnb',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'soleil soleil',
#   'popularity': 58,
#   'preview_url': None,
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:6m3ObG4d6M92hJWYplJfnb'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#      'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#      'id': '6e3pZKXUxrPfnUPJ960Hd9',
#      'name': 'Pomme',
#      'type': 'artist',
#      'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3Iq43NGfIN8tc8AVJ9Konz'},
#    'href': 'https://api.spotify.com/v1/albums/3Iq43NGfIN8tc8AVJ9Konz',
#    'id': '3Iq43NGfIN8tc8AVJ9Konz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27330bc1c0c2e0d7cb718f856f2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0230bc1c0c2e0d7cb718f856f2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485130bc1c0c2e0d7cb718f856f2',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'les failles',
#    'release_date': '2019-11-01',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:3Iq43NGfIN8tc8AVJ9Konz'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#     'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#     'id': '6e3pZKXUxrPfnUPJ960Hd9',
#     'name': 'Pomme',
#     'type': 'artist',
#     'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#   'disc_number': 1,
#   'duration_ms': 138746,
#   'explicit': False,
#   'external_ids': {'isrc': 'FRUM71900915'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7FMDhuPk4KiG2Y1DV7y56c'},
#   'href': 'https://api.spotify.com/v1/tracks/7FMDhuPk4KiG2Y1DV7y56c',
#   'id': '7FMDhuPk4KiG2Y1DV7y56c',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'je sais pas danser',
#   'popularity': 57,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:7FMDhuPk4KiG2Y1DV7y56c'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#      'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#      'id': '6e3pZKXUxrPfnUPJ960Hd9',
#      'name': 'Pomme',
#      'type': 'artist',
#      'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/65JwIioaq6D5ExpRdtYpCM'},
#    'href': 'https://api.spotify.com/v1/albums/65JwIioaq6D5ExpRdtYpCM',
#    'id': '65JwIioaq6D5ExpRdtYpCM',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736ada6a0f014e5ca796561339',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026ada6a0f014e5ca796561339',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516ada6a0f014e5ca796561339',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'À peu près',
#    'release_date': '2017-10-06',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:65JwIioaq6D5ExpRdtYpCM'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#     'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#     'id': '6e3pZKXUxrPfnUPJ960Hd9',
#     'name': 'Pomme',
#     'type': 'artist',
#     'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#   'disc_number': 1,
#   'duration_ms': 207320,
#   'explicit': False,
#   'external_ids': {'isrc': 'FRUM71700925'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/52APn0QJbjtcHRK0fiXpL6'},
#   'href': 'https://api.spotify.com/v1/tracks/52APn0QJbjtcHRK0fiXpL6',
#   'id': '52APn0QJbjtcHRK0fiXpL6',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'On brûlera',
#   'popularity': 56,
#   'preview_url': None,
#   'track_number': 12,
#   'type': 'track',
#   'uri': 'spotify:track:52APn0QJbjtcHRK0fiXpL6'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/73BDzWqbf1grbgQ8xYn2ou'},
#      'href': 'https://api.spotify.com/v1/artists/73BDzWqbf1grbgQ8xYn2ou',
#      'id': '73BDzWqbf1grbgQ8xYn2ou',
#      'name': 'Ben Mazué',
#      'type': 'artist',
#      'uri': 'spotify:artist:73BDzWqbf1grbgQ8xYn2ou'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2cpyU2HuvpC3LyCHJn12XO'},
#    'href': 'https://api.spotify.com/v1/albums/2cpyU2HuvpC3LyCHJn12XO',
#    'id': '2cpyU2HuvpC3LyCHJn12XO',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273da73a627d6ab787227306490',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02da73a627d6ab787227306490',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851da73a627d6ab787227306490',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Les femmes idéales',
#    'release_date': '2018-11-09',
#    'release_date_precision': 'day',
#    'total_tracks': 17,
#    'type': 'album',
#    'uri': 'spotify:album:2cpyU2HuvpC3LyCHJn12XO'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/73BDzWqbf1grbgQ8xYn2ou'},
#     'href': 'https://api.spotify.com/v1/artists/73BDzWqbf1grbgQ8xYn2ou',
#     'id': '73BDzWqbf1grbgQ8xYn2ou',
#     'name': 'Ben Mazué',
#     'type': 'artist',
#     'uri': 'spotify:artist:73BDzWqbf1grbgQ8xYn2ou'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#     'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#     'id': '6e3pZKXUxrPfnUPJ960Hd9',
#     'name': 'Pomme',
#     'type': 'artist',
#     'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#   'disc_number': 1,
#   'duration_ms': 280826,
#   'explicit': False,
#   'external_ids': {'isrc': 'FRZ051800506'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2EjSObddqmZPzlcoket9WV'},
#   'href': 'https://api.spotify.com/v1/tracks/2EjSObddqmZPzlcoket9WV',
#   'id': '2EjSObddqmZPzlcoket9WV',
#   'is_local': False,
#   'is_playable': True,
#   'name': "J'attends",
#   'popularity': 56,
#   'preview_url': 'https://p.scdn.co/mp3-preview/acc7d190161b488da5d7c23d6a2fc82c642c6182?cid=afb7e3d8170141e0a73470e95e2757ec',
#   'track_number': 15,
#   'type': 'track',
#   'uri': 'spotify:track:2EjSObddqmZPzlcoket9WV'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#      'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#      'id': '6e3pZKXUxrPfnUPJ960Hd9',
#      'name': 'Pomme',
#      'type': 'artist',
#      'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3Iq43NGfIN8tc8AVJ9Konz'},
#    'href': 'https://api.spotify.com/v1/albums/3Iq43NGfIN8tc8AVJ9Konz',
#    'id': '3Iq43NGfIN8tc8AVJ9Konz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27330bc1c0c2e0d7cb718f856f2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0230bc1c0c2e0d7cb718f856f2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485130bc1c0c2e0d7cb718f856f2',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'les failles',
#    'release_date': '2019-11-01',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:3Iq43NGfIN8tc8AVJ9Konz'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#     'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#     'id': '6e3pZKXUxrPfnUPJ960Hd9',
#     'name': 'Pomme',
#     'type': 'artist',
#     'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#   'disc_number': 1,
#   'duration_ms': 230826,
#   'explicit': False,
#   'external_ids': {'isrc': 'FRUM71900914'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1HYiZbH7QTKfOUe9AmvbJr'},
#   'href': 'https://api.spotify.com/v1/tracks/1HYiZbH7QTKfOUe9AmvbJr',
#   'id': '1HYiZbH7QTKfOUe9AmvbJr',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'anxiété',
#   'popularity': 51,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:1HYiZbH7QTKfOUe9AmvbJr'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#      'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#      'id': '6e3pZKXUxrPfnUPJ960Hd9',
#      'name': 'Pomme',
#      'type': 'artist',
#      'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3Iq43NGfIN8tc8AVJ9Konz'},
#    'href': 'https://api.spotify.com/v1/albums/3Iq43NGfIN8tc8AVJ9Konz',
#    'id': '3Iq43NGfIN8tc8AVJ9Konz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27330bc1c0c2e0d7cb718f856f2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0230bc1c0c2e0d7cb718f856f2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485130bc1c0c2e0d7cb718f856f2',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'les failles',
#    'release_date': '2019-11-01',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:3Iq43NGfIN8tc8AVJ9Konz'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#     'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#     'id': '6e3pZKXUxrPfnUPJ960Hd9',
#     'name': 'Pomme',
#     'type': 'artist',
#     'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#   'disc_number': 1,
#   'duration_ms': 195280,
#   'explicit': False,
#   'external_ids': {'isrc': 'FRUM71900916'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3NakEPSaVKsqqimJW66xCc'},
#   'href': 'https://api.spotify.com/v1/tracks/3NakEPSaVKsqqimJW66xCc',
#   'id': '3NakEPSaVKsqqimJW66xCc',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'grandiose',
#   'popularity': 51,
#   'preview_url': None,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:3NakEPSaVKsqqimJW66xCc'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#      'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#      'id': '6e3pZKXUxrPfnUPJ960Hd9',
#      'name': 'Pomme',
#      'type': 'artist',
#      'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4EHRNl8rET8Ve72UQB2cLe'},
#    'href': 'https://api.spotify.com/v1/albums/4EHRNl8rET8Ve72UQB2cLe',
#    'id': '4EHRNl8rET8Ve72UQB2cLe',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27367d0edf257365b2ed5a1b8e3',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0267d0edf257365b2ed5a1b8e3',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485167d0edf257365b2ed5a1b8e3',
#      'width': 64}],
#    'is_playable': True,
#    'name': '_jun perseides',
#    'release_date': '2024-02-29',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:4EHRNl8rET8Ve72UQB2cLe'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#     'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#     'id': '6e3pZKXUxrPfnUPJ960Hd9',
#     'name': 'Pomme',
#     'type': 'artist',
#     'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'}],
#   'disc_number': 1,
#   'duration_ms': 176040,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR9W12363225'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5PRUmgnoIQIi3tVVRBYD10'},
#   'href': 'https://api.spotify.com/v1/tracks/5PRUmgnoIQIi3tVVRBYD10',
#   'id': '5PRUmgnoIQIi3tVVRBYD10',
#   'is_local': False,
#   'is_playable': True,
#   'name': '_jun perseides',
#   'popularity': 51,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:5PRUmgnoIQIi3tVVRBYD10'}]

# %%
#Finally, display the top ten songs of the artist!
for idx, song in enumerate(songs):
    print(f"{idx + 1}. {song['name']}")
# Out:
# 1. Ceux qui rêvent
# 2. Laissez-moi danser
# 3. Le grand cirque
# 4. soleil soleil
# 5. je sais pas danser
# 6. On brûlera
# 7. J'attends
# 8. anxiété
# 9. grandiose
# 10. _jun perseides
